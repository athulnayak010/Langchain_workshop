# %% [markdown]
# <a href="https://colab.research.google.com/github/athulnayak010/Langchain_workshop/blob/main/object_detection_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/Colab\ Notebooks/object_detection_project.zip -d /content/object_detection_project
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/object_detection_project/object_detection_project/VOC2012/SegmentationClass/2008_001882.png
#   inflating: /content/object_detection_project/object_detection_project/VOC2012/SegmentationClass/2008_001885.png
#   inflating: /content/object_detection_project/object_detection_project/VOC2012/SegmentationClass/2008_001895.png
#   inflating: /content/object_detection_project/object_detection_project/VOC2012/SegmentationClass/2008_001896.png
#   inflating: /content/object_detection_project/object_detection_project/VOC2012/SegmentationClass/2008_001926.png
#   inflating: /content/object_detection_project/object_detection_project/VOC2012/SegmentationClass/2008_001966.png
#   inflating: /content/object_detection_project/object_detection_project/VOC2012/SegmentationClass/2008_001971.png
#   inflating: /content/object_detection_project/object_detection_project/VOC2012/SegmentationClass/2008_001992.png
# ...

# %%
# %cd /content/object_detection_project/object_detection_project
# Out:
# /content/object_detection_project/object_detection_project

# %%
# !pip install ultralytics opencv-python pillow numpy matplotlib tqdm fastapi uvicorn python-multipart
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 25.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  # load pretrained model
model.info()  # show model details
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# YOLOv8n summary: 129 layers, 3,157,200 parameters, 0 gradients, 8.9 GFLOPs
# (129, 3157200, 0, 8.8575488)

# %%
# !yolo train data=data.yaml model=yolov8n.pt epochs=50 imgsz=640 batch=16 device=0 workers=2 name=voc_model
# Out:
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
